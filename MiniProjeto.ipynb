# %% [markdown]
# <a href="https://colab.research.google.com/github/MKL0pes/ENGENHARIA_DE_PROMPT/blob/main/MiniProjeto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade de programação assistida por AI
#  mayck gabriel

# %% [markdown]
# soma de lista

# %%
numeros = [1, 2, 3 , 4 , 5 , 6 ]
soma = 0
i = 0
while i < len (numeros):
  soma += numeros[i]
  i += 1
  print(soma)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21

# %%
import math

def eh_primo(n):
    for i in range(2, int(math.sqrt(n)) + 1):
        if n % i == 0:
            return False
    return True

# %%
def invert_texto(texto):
  return texto[::-1]
